# %% [markdown]
# ## 2. Discrete Fourier Transforms of Various Signals
#
# **The following are exercises from Chapter 7 of Mark Newman's Computational Physics book.**

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# For all problems, take $N = 1,000$

# %% [markdown]
# 2.1 Perform a DFT on a single period of a square wave of amplitude 1. Plot the wave and the magnitude spectrum, $|c_{k}|$.

# %%
def square_filter(x):
    if x >= 0:
        return 1
    else:
        return 0

T = 5
N = 1000
t = np.linspace(0, T,  N)
y = [square_filter(i) for i in np.sin(2*np.pi*t/T)]
# or just 
# y = np.round((np.sin(2*np.pi*t/T) + 1) / 2)

fig, ax = plt.subplots()
ax.plot(t, y)
fig, ax = plt.subplots()
ax.plot(t[:501], np.fft.rfft(y))
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# /Users/noahthompson/Downloads/anaconda/lib/python3.5/site-packages/numpy/core/numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# 2.2 Perform a DFT for the sawtooth wave: $y_{n} = n$. Plot the "wave" (it's just a line..) and the magnitude spectrum, $|c_{k}|$.

# %%
N = 1000
y = np.arange(N)
fig, ax = plt.subplots()
ax.plot(t, y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# 2.3 Perform a DFT for the modulated wave: $\sin(\frac{\pi t}{L}) \sin(\frac{20 \pi t}{L})$. Plot the wave and the magnitude spectrum, $|c_{k}|$.

# %%
N = 1000
y = np.sin((np.pi * np.arange(N))/1000)*np.sin(20*np.pi*np.arange(N)/1000)
fig, ax = plt.subplots()
ax.plot(t, y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# 2.4 Perform a DFT of noisy signal that is centered around 0

# %%
N = 1000
t = np.linspace(0, 5, 1000)
y = noise(t)
fig, ax = plt.subplots()
ax.plot(t[:501], np.abs(np.fft.rfft(y)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-143ed56d6a9c> in <module>()
#       1 N = 1000
#       2 t = np.linspace(0, 5, 1000)
# ----> 3 y = noise(t)
#       4 fig, ax = plt.subplots()
#       5 ax.plot(t[:501], np.abs(np.fft.rfft(y)))
#
# NameError: name 'noise' is not defined
